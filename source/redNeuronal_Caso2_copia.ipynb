# %%
#CASO 3: Predicción de la demanda de 5 productos top de una empresa
import pyodbc
import pandas as pd
import numpy as np
from datetime import date, datetime, timedelta
from dateutil.relativedelta import relativedelta
import matplotlib.pylab as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest

plt.rcParams['figure.figsize' ] = (16, 9)
plt.style.use('fast')

# %%
sql_server="""
DRIVER={ODBC Driver 17 for SQL Server};
Server=US3RN4M3;
database=demo_prediccion;
Trusted_connection=yes;
"""

# %%
query = """


"""


query_suc = """

"""


# query = """
# SELECT
# [F]. [Fecha] AS fecha,
# SUM([H]. [cantidad]) AS cantidad
# FROM
# [demo_prediccion]. [dbo]. [hechos] AS [H]
# INNER JOIN [demo_prediccion]. [dbo]. [Dim_fechas] AS [f] ON [H].[id_DimFechas] = [F].[id]
# GROUP BY [F].[Fecha]
# """

# %%
#Configuración para el entrenamiento (hace referencia a dias)
PASOS = 12

# %%
#Opcion 1: Permitir que pueda ser modificada la sentencia, y mantenrr el try para evitar de que
# el programa se rompa

def get_sqlconnection(config_sqlServer):
    status = "inicializando...."
    try: 
        connection = pyodbc.connect(sql_server)
        status = "Conexion establecida satisfactoriamente"
    except Exception as e:
        status = "Error al establecer la conexión:"+e
    print(status)
    return connection

#Original:
# def get_sqlconnection(config_sqlServer):
#     connection = pyodbc.connect(config_sqlServer)
#     print("Se ha conectado a la base de datos")
#     return connection

# %%
def set_index_datetime(data):
    if str(type(data) == "<class 'pandas.core.frame.DataFrame'>"):
        # data.sort_values('fecha', inplace=True)
        for column in data.columns: 
            try: 
                pd.to_datetime(data[column])
                data.set_index(column,inplace=True)
                return data
            except Exception as e:  
                pass
    else: 
        return 0
    
# def set_index_datetime(data):
#     if isinstance(data, pd.DataFrame):
#         for column in data.columns:
#             try:
#                 if column == 'fecha':
#                     data[column] = pd.to_datetime(data[column])
#                     data.set_index(column, inplace=True)

#                 data = data.groupby('fecha').sum().reset_index()
#                 data.dropna(inplace=True)
#                 return data
#                 # data[column] = pd.to_datetime(data[column])
#                 # data.set_index(column, inplace=True)
#                 # return data
#             except Exception as e:
#                 print(f"Error al convertir la columna {column} a datetime: {e}")
#                 pass
#     else:
#         return 0

# %%
# with get_sqlconnection(sql_server) as cursor:
#     data = pd.read_sql_query(query,cursor)
#     print(data)
#     data.plot()

#     data = set_index_datetime(data)
#     print(data)

#     data.plot()

# %%
def series_to_supervised(data, n_in=1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in,0,-1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1,i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var&d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def create_x_y_train(data):
    values = data.values
    values = values.astype('float32')
    scaler = MinMaxScaler(feature_range=(-1, 1))
    values= values.reshape(-1, 1)
    scaled = scaler.fit_transform(values)
    reframed = series_to_supervised(scaled, PASOS, 1)
    values = reframed.values
    n_train_days = int(len(data)) - (30+PASOS)
    train = values[:n_train_days, :]
    test = values[n_train_days:, :]
    x_train, y_train = train[:, :- 1], train[:, -1]
    x_val, y_val = test[:, :- 1], test[:, -1]
    x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
    x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
    return x_train, y_train, x_val, y_val, scaler, values

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error', optimizer='Adam',metrics=['mse' ])
    model.summary()
    return model

# %%
def entrenar_modelo(x_train, y_train, x_val, y_val, scaler, values, data, model) :
    EPOCHS = 100
    model.fit(x_train, y_train, epochs=EPOCHS, validation_data=(x_val, y_val), batch_size=PASOS)
    model.predict(x_val)
    ultimosDias = data[data.index[int(len(data)*0.70)]:]
    values = ultimosDias.values
    values = values.astype('float32' )
    values = values.reshape(-1, 1)
    scaled = values
    reframed = series_to_supervised(scaled, PASOS, 1)
    reframed.drop(reframed.columns[[12]], axis=1, inplace=True)
    values = ultimosDias.values
    values = values.astype('float32' )
    values = values.reshape(-1, 1)
    scaled = scaler.fit_transform(values)
    reframed = series_to_supervised(scaled, PASOS, 1)
    reframed.drop(reframed.columns[[12]], axis=1, inplace=True)
    values = reframed.values
    x_test = values[len(values)-1:, :]
    x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]) )
    return model, x_test

# %%
def agregarNuevoValor(x_test, nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test. shape[2]-1] = nuevoValor
    return x_test

# %%
def eliminar_anomalias(dtaframe):
    dataFrame_anomalias = dtaframe.copy()
    modeloIsolation = IsolationForest(contamination=0.05)
    modeloIsolation.fit(dataFrame_anomalias)
    anomalias = modeloIsolation.predict(dataFrame_anomalias)
    dtaframe['anomalias' ] = anomalias
    dataFrameSinAnomalias = dtaframe[dtaframe['anomalias' ] != -1]
    dataFrameSinAnomalias = dataFrameSinAnomalias.drop('anomalias', axis=1)
    return dataFrameSinAnomalias

# %%
#El Core del sistema
with get_sqlconnection(sql_server) as cursor:
    datos = pd.read_sql_query(query, cursor)
    datos = set_index_datetime(datos)
    # datos.plot()

    #Predicción de acuerdo a la oultima fecha registrada que fue en el 2020-12-31
    last_day = datetime.strptime(datos.index.max(), '%Y-%m' ) + relativedelta(months=1)
    # print(last_day)

    #Predicción que se hará de acierdo a los pasos que se han definido 
    future_days = [last_day + relativedelta(months=i) for i in range(PASOS)]
    # future_days = [last_day + relativedelta(days=i) for i in range(1, PASOS+1)]
    # print(future_days)

    #Reesctructuramos los datos que se han obtenido, tomando solo los ultimos 10 digitos
    #future_days = [str(i)[:10] for i in future_days]
    for i in range(len(future_days)):
        future_days[i] = str(future_days[i])[:10]
    print(future_days)

    #Cremos un arreglo para poder tomar todas las fechas
    #Que servirá para predecir fechas futuras
    future_data = pd.DataFrame(future_days)
    future_data.columns = ['fecha']
# Out:
# Conexion establecida satisfactoriamente
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_11412\1419587430.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql_query(query, cursor)
# ['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01']

# %%
    

    #Creamos un modelo de datos
    model = crear_modeloFF()
    for column in datos.columns:
        data = datos.filter([column])
        data.set_index(datos.index, inplace=True)
        data = eliminar_anomalias(data)
        x_train, y_train, x_val, y_val, scaler, values = create_x_y_train(data)
        model, x_test = entrenar_modelo(x_train, y_train, x_val, y_val, scaler, values, data, model)
        results = []
        for i in range(PASOS):
            parcial = model.predict(x_test)
            results.append(parcial[0])
            x_test = agregarNuevoValor(x_test, parcial[0])
        adimen = [x for x in results]
        inverted = scaler.inverse_transform(adimen)
        y_pred = pd.DataFrame(inverted.astype(int))
        future_data[column]= inverted.astype(int)
    future_data = set_index_datetime(future_data)
    print(future_data)
# Out:
# c:\Residencia_proyecto\PRONOSTICO\PRONOSTICO_DE_INVENTARIOS\4.- Recursos\prediccion\envprediccion\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 12)          │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 169 (676.00 B)
#  Trainable params: 169 (676.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.3620 - mse: 0.1919 - val_loss: 0.6366 - val_mse: 0.5610
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3784 - mse: 0.2069 - val_loss: 0.6274 - val_mse: 0.5478
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3659 - mse: 0.1867 - val_loss: 0.6157 - val_mse: 0.5322
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3659 - mse: 0.1881 - val_loss: 0.6058 - val_mse: 0.5198
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3553 - mse: 0.1870 - val_loss: 0.5949 - val_mse: 0.5065
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3501 - mse: 0.1739 - val_loss: 0.5837 - val_mse: 0.4930
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3135 - mse: 0.1452 - val_loss: 0.5711 - val_mse: 0.4785
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3380 - mse: 0.1621 - val_loss: 0.5613 - val_mse: 0.4664
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3282 - mse: 0.1659 - val_loss: 0.5510 - val_mse: 0.4542
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3182 - mse: 0.1516 - val_loss: 0.5394 - val_mse: 0.4418
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2893 - mse: 0.1280 - val_loss: 0.5288 - val_mse: 0.4311
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3004 - mse: 0.1402 - val_loss: 0.5215 - val_mse: 0.4226
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2951 - mse: 0.1305 - val_loss: 0.5144 - val_mse: 0.4140
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3074 - mse: 0.1379 - val_loss: 0.5070 - val_mse: 0.4059
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3009 - mse: 0.1309 - val_loss: 0.4998 - val_mse: 0.3981
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2667 - mse: 0.1109 - val_loss: 0.4914 - val_mse: 0.3901
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2808 - mse: 0.1174 - val_loss: 0.4822 - val_mse: 0.3826
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2851 - mse: 0.1165 - val_loss: 0.4712 - val_mse: 0.3758
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2629 - mse: 0.1097 - val_loss: 0.4603 - val_mse: 0.3704
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2532 - mse: 0.1078 - val_loss: 0.4531 - val_mse: 0.3657
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2542 - mse: 0.1015 - val_loss: 0.4481 - val_mse: 0.3606
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2613 - mse: 0.1090 - val_loss: 0.4450 - val_mse: 0.3551
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2425 - mse: 0.0971 - val_loss: 0.4433 - val_mse: 0.3499
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2383 - mse: 0.0903 - val_loss: 0.4411 - val_mse: 0.3450
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2660 - mse: 0.1057 - val_loss: 0.4367 - val_mse: 0.3408
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2435 - mse: 0.0964 - val_loss: 0.4313 - val_mse: 0.3365
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2645 - mse: 0.1059 - val_loss: 0.4255 - val_mse: 0.3327
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2518 - mse: 0.1006 - val_loss: 0.4177 - val_mse: 0.3300
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2376 - mse: 0.0911 - val_loss: 0.4113 - val_mse: 0.3274
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2275 - mse: 0.0891 - val_loss: 0.4054 - val_mse: 0.3247
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2265 - mse: 0.0859 - val_loss: 0.4000 - val_mse: 0.3222
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2471 - mse: 0.1015 - val_loss: 0.3963 - val_mse: 0.3204
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2136 - mse: 0.0800 - val_loss: 0.3935 - val_mse: 0.3180
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2308 - mse: 0.0892 - val_loss: 0.3913 - val_mse: 0.3153
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2300 - mse: 0.0887 - val_loss: 0.3892 - val_mse: 0.3129
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2338 - mse: 0.0879 - val_loss: 0.3876 - val_mse: 0.3117
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2272 - mse: 0.0883 - val_loss: 0.3860 - val_mse: 0.3103
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2144 - mse: 0.0788 - val_loss: 0.3846 - val_mse: 0.3093
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2155 - mse: 0.0847 - val_loss: 0.3830 - val_mse: 0.3083
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2220 - mse: 0.0835 - val_loss: 0.3816 - val_mse: 0.3065
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2063 - mse: 0.0765 - val_loss: 0.3808 - val_mse: 0.3037
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2098 - mse: 0.0756 - val_loss: 0.3800 - val_mse: 0.3014
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2133 - mse: 0.0781 - val_loss: 0.3790 - val_mse: 0.2998
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2228 - mse: 0.0824 - val_loss: 0.3779 - val_mse: 0.2996
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1959 - mse: 0.0669 - val_loss: 0.3769 - val_mse: 0.2987
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2087 - mse: 0.0743 - val_loss: 0.3760 - val_mse: 0.2971
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2033 - mse: 0.0690 - val_loss: 0.3756 - val_mse: 0.2969
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2173 - mse: 0.0810 - val_loss: 0.3752 - val_mse: 0.2966
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1906 - mse: 0.0673 - val_loss: 0.3749 - val_mse: 0.2939
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2022 - mse: 0.0722 - val_loss: 0.3741 - val_mse: 0.2905
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2145 - mse: 0.0771 - val_loss: 0.3728 - val_mse: 0.2872
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2276 - mse: 0.0822 - val_loss: 0.3723 - val_mse: 0.2844
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2139 - mse: 0.0771 - val_loss: 0.3720 - val_mse: 0.2836
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2120 - mse: 0.0748 - val_loss: 0.3709 - val_mse: 0.2831
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2114 - mse: 0.0749 - val_loss: 0.3695 - val_mse: 0.2826
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2081 - mse: 0.0711 - val_loss: 0.3679 - val_mse: 0.2823
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2241 - mse: 0.0805 - val_loss: 0.3661 - val_mse: 0.2810
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2020 - mse: 0.0705 - val_loss: 0.3649 - val_mse: 0.2773
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2079 - mse: 0.0717 - val_loss: 0.3644 - val_mse: 0.2732
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2093 - mse: 0.0732 - val_loss: 0.3642 - val_mse: 0.2686
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2048 - mse: 0.0685 - val_loss: 0.3637 - val_mse: 0.2649
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1909 - mse: 0.0611 - val_loss: 0.3630 - val_mse: 0.2629
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1991 - mse: 0.0644 - val_loss: 0.3614 - val_mse: 0.2620
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2007 - mse: 0.0669 - val_loss: 0.3597 - val_mse: 0.2628
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2204 - mse: 0.0760 - val_loss: 0.3576 - val_mse: 0.2646
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1988 - mse: 0.0679 - val_loss: 0.3565 - val_mse: 0.2665
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2124 - mse: 0.0765 - val_loss: 0.3559 - val_mse: 0.2681
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2006 - mse: 0.0681 - val_loss: 0.3560 - val_mse: 0.2687
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2019 - mse: 0.0695 - val_loss: 0.3562 - val_mse: 0.2672
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2004 - mse: 0.0650 - val_loss: 0.3555 - val_mse: 0.2648
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1938 - mse: 0.0622 - val_loss: 0.3551 - val_mse: 0.2607
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1974 - mse: 0.0653 - val_loss: 0.3549 - val_mse: 0.2564
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1973 - mse: 0.0655 - val_loss: 0.3542 - val_mse: 0.2532
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2138 - mse: 0.0737 - val_loss: 0.3530 - val_mse: 0.2519
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1982 - mse: 0.0648 - val_loss: 0.3515 - val_mse: 0.2501
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2002 - mse: 0.0647 - val_loss: 0.3498 - val_mse: 0.2487
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1937 - mse: 0.0613 - val_loss: 0.3480 - val_mse: 0.2479
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1823 - mse: 0.0558 - val_loss: 0.3471 - val_mse: 0.2471
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1991 - mse: 0.0642 - val_loss: 0.3460 - val_mse: 0.2462
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1793 - mse: 0.0548 - val_loss: 0.3445 - val_mse: 0.2444
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1715 - mse: 0.0518 - val_loss: 0.3428 - val_mse: 0.2419
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1967 - mse: 0.0645 - val_loss: 0.3416 - val_mse: 0.2389
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1799 - mse: 0.0538 - val_loss: 0.3399 - val_mse: 0.2361
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1972 - mse: 0.0608 - val_loss: 0.3389 - val_mse: 0.2335
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1724 - mse: 0.0505 - val_loss: 0.3387 - val_mse: 0.2311
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1740 - mse: 0.0516 - val_loss: 0.3386 - val_mse: 0.2290
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1833 - mse: 0.0539 - val_loss: 0.3379 - val_mse: 0.2280
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1797 - mse: 0.0533 - val_loss: 0.3380 - val_mse: 0.2286
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1826 - mse: 0.0546 - val_loss: 0.3384 - val_mse: 0.2293
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1692 - mse: 0.0482 - val_loss: 0.3379 - val_mse: 0.2283
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1812 - mse: 0.0519 - val_loss: 0.3376 - val_mse: 0.2270
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1963 - mse: 0.0610 - val_loss: 0.3366 - val_mse: 0.2264
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1792 - mse: 0.0520 - val_loss: 0.3344 - val_mse: 0.2259
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1783 - mse: 0.0520 - val_loss: 0.3336 - val_mse: 0.2249
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1775 - mse: 0.0529 - val_loss: 0.3338 - val_mse: 0.2229
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1771 - mse: 0.0514 - val_loss: 0.3341 - val_mse: 0.2205
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1843 - mse: 0.0557 - val_loss: 0.3349 - val_mse: 0.2191
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1782 - mse: 0.0528 - val_loss: 0.3349 - val_mse: 0.2179
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1809 - mse: 0.0525 - val_loss: 0.3339 - val_mse: 0.2164
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1799 - mse: 0.0536 - val_loss: 0.3323 - val_mse: 0.2148
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_11412\2297903707.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test. shape[2]-1] = nuevoValor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2306 - mse: 0.0854 - val_loss: 0.3521 - val_mse: 0.1729
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2145 - mse: 0.0715 - val_loss: 0.3509 - val_mse: 0.1725
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2151 - mse: 0.0705 - val_loss: 0.3507 - val_mse: 0.1733
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2042 - mse: 0.0666 - val_loss: 0.3511 - val_mse: 0.1750
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2076 - mse: 0.0682 - val_loss: 0.3520 - val_mse: 0.1776
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1874 - mse: 0.0553 - val_loss: 0.3540 - val_mse: 0.1818
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1846 - mse: 0.0600 - val_loss: 0.3575 - val_mse: 0.1869
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2046 - mse: 0.0731 - val_loss: 0.3620 - val_mse: 0.1921
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1910 - mse: 0.0648 - val_loss: 0.3672 - val_mse: 0.1959
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1929 - mse: 0.0682 - val_loss: 0.3719 - val_mse: 0.1996
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1934 - mse: 0.0670 - val_loss: 0.3752 - val_mse: 0.2025
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1963 - mse: 0.0659 - val_loss: 0.3780 - val_mse: 0.2049
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1831 - mse: 0.0642 - val_loss: 0.3794 - val_mse: 0.2061
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1773 - mse: 0.0570 - val_loss: 0.3778 - val_mse: 0.2044
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1866 - mse: 0.0608 - val_loss: 0.3739 - val_mse: 0.2005
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1661 - mse: 0.0514 - val_loss: 0.3710 - val_mse: 0.1976
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1667 - mse: 0.0531 - val_loss: 0.3698 - val_mse: 0.1961
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1727 - mse: 0.0545 - val_loss: 0.3672 - val_mse: 0.1935
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1642 - mse: 0.0455 - val_loss: 0.3657 - val_mse: 0.1919
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1569 - mse: 0.0426 - val_loss: 0.3647 - val_mse: 0.1908
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1597 - mse: 0.0430 - val_loss: 0.3667 - val_mse: 0.1923
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1801 - mse: 0.0551 - val_loss: 0.3708 - val_mse: 0.1959
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1741 - mse: 0.0547 - val_loss: 0.3755 - val_mse: 0.2002
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1547 - mse: 0.0432 - val_loss: 0.3783 - val_mse: 0.2028
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1448 - mse: 0.0419 - val_loss: 0.3806 - val_mse: 0.2050
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1620 - mse: 0.0494 - val_loss: 0.3827 - val_mse: 0.2070
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1703 - mse: 0.0533 - val_loss: 0.3845 - val_mse: 0.2088
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1532 - mse: 0.0462 - val_loss: 0.3843 - val_mse: 0.2087
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1652 - mse: 0.0485 - val_loss: 0.3850 - val_mse: 0.2095
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1538 - mse: 0.0460 - val_loss: 0.3869 - val_mse: 0.2114
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1461 - mse: 0.0371 - val_loss: 0.3883 - val_mse: 0.2127
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1612 - mse: 0.0483 - val_loss: 0.3906 - val_mse: 0.2148
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1477 - mse: 0.0421 - val_loss: 0.3933 - val_mse: 0.2174
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1529 - mse: 0.0442 - val_loss: 0.3968 - val_mse: 0.2207
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1465 - mse: 0.0407 - val_loss: 0.3992 - val_mse: 0.2229
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1314 - mse: 0.0319 - val_loss: 0.4018 - val_mse: 0.2256
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1498 - mse: 0.0440 - val_loss: 0.4026 - val_mse: 0.2264
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1365 - mse: 0.0378 - val_loss: 0.4029 - val_mse: 0.2268
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1428 - mse: 0.0408 - val_loss: 0.4027 - val_mse: 0.2265
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1379 - mse: 0.0377 - val_loss: 0.4021 - val_mse: 0.2259
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1341 - mse: 0.0313 - val_loss: 0.4010 - val_mse: 0.2248
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1361 - mse: 0.0326 - val_loss: 0.4018 - val_mse: 0.2255
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1345 - mse: 0.0347 - val_loss: 0.4016 - val_mse: 0.2252
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1402 - mse: 0.0379 - val_loss: 0.4020 - val_mse: 0.2255
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1267 - mse: 0.0297 - val_loss: 0.4025 - val_mse: 0.2259
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1218 - mse: 0.0284 - val_loss: 0.4038 - val_mse: 0.2269
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1326 - mse: 0.0323 - val_loss: 0.4044 - val_mse: 0.2274
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1204 - mse: 0.0284 - val_loss: 0.4044 - val_mse: 0.2274
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1345 - mse: 0.0341 - val_loss: 0.4039 - val_mse: 0.2269
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1260 - mse: 0.0302 - val_loss: 0.4019 - val_mse: 0.2250
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1338 - mse: 0.0340 - val_loss: 0.3996 - val_mse: 0.2229
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1311 - mse: 0.0290 - val_loss: 0.3999 - val_mse: 0.2231
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1379 - mse: 0.0338 - val_loss: 0.4041 - val_mse: 0.2266
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1280 - mse: 0.0287 - val_loss: 0.4085 - val_mse: 0.2304
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1222 - mse: 0.0287 - val_loss: 0.4132 - val_mse: 0.2345
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1252 - mse: 0.0298 - val_loss: 0.4181 - val_mse: 0.2391
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1264 - mse: 0.0312 - val_loss: 0.4203 - val_mse: 0.2412
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1132 - mse: 0.0245 - val_loss: 0.4218 - val_mse: 0.2428
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1242 - mse: 0.0307 - val_loss: 0.4241 - val_mse: 0.2451
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1069 - mse: 0.0230 - val_loss: 0.4250 - val_mse: 0.2461
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1193 - mse: 0.0285 - val_loss: 0.4257 - val_mse: 0.2470
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1130 - mse: 0.0249 - val_loss: 0.4284 - val_mse: 0.2497
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1078 - mse: 0.0224 - val_loss: 0.4298 - val_mse: 0.2512
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1175 - mse: 0.0279 - val_loss: 0.4308 - val_mse: 0.2524
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1118 - mse: 0.0235 - val_loss: 0.4324 - val_mse: 0.2541
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1223 - mse: 0.0295 - val_loss: 0.4315 - val_mse: 0.2533
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1148 - mse: 0.0267 - val_loss: 0.4292 - val_mse: 0.2511
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1123 - mse: 0.0242 - val_loss: 0.4284 - val_mse: 0.2505
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1278 - mse: 0.0297 - val_loss: 0.4272 - val_mse: 0.2496
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1138 - mse: 0.0272 - val_loss: 0.4281 - val_mse: 0.2505
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1119 - mse: 0.0238 - val_loss: 0.4299 - val_mse: 0.2523
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1138 - mse: 0.0257 - val_loss: 0.4318 - val_mse: 0.2541
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1065 - mse: 0.0243 - val_loss: 0.4321 - val_mse: 0.2546
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1093 - mse: 0.0252 - val_loss: 0.4310 - val_mse: 0.2538
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1185 - mse: 0.0275 - val_loss: 0.4303 - val_mse: 0.2533
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1140 - mse: 0.0258 - val_loss: 0.4295 - val_mse: 0.2528
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1235 - mse: 0.0289 - val_loss: 0.4291 - val_mse: 0.2525
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1049 - mse: 0.0214 - val_loss: 0.4282 - val_mse: 0.2518
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1206 - mse: 0.0279 - val_loss: 0.4287 - val_mse: 0.2524
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1244 - mse: 0.0286 - val_loss: 0.4311 - val_mse: 0.2547
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1081 - mse: 0.0220 - val_loss: 0.4355 - val_mse: 0.2589
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1105 - mse: 0.0228 - val_loss: 0.4399 - val_mse: 0.2633
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1172 - mse: 0.0265 - val_loss: 0.4410 - val_mse: 0.2644
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1100 - mse: 0.0223 - val_loss: 0.4411 - val_mse: 0.2646
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1237 - mse: 0.0287 - val_loss: 0.4440 - val_mse: 0.2674
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1063 - mse: 0.0223 - val_loss: 0.4470 - val_mse: 0.2703
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1185 - mse: 0.0249 - val_loss: 0.4469 - val_mse: 0.2701
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1116 - mse: 0.0263 - val_loss: 0.4458 - val_mse: 0.2690
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1122 - mse: 0.0232 - val_loss: 0.4448 - val_mse: 0.2680
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1123 - mse: 0.0256 - val_loss: 0.4439 - val_mse: 0.2671
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0980 - mse: 0.0187 - val_loss: 0.4439 - val_mse: 0.2671
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1058 - mse: 0.0231 - val_loss: 0.4429 - val_mse: 0.2661
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1075 - mse: 0.0232 - val_loss: 0.4417 - val_mse: 0.2651
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1056 - mse: 0.0234 - val_loss: 0.4392 - val_mse: 0.2628
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1141 - mse: 0.0252 - val_loss: 0.4371 - val_mse: 0.2611
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1015 - mse: 0.0203 - val_loss: 0.4386 - val_mse: 0.2628
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1049 - mse: 0.0208 - val_loss: 0.4413 - val_mse: 0.2656
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1106 - mse: 0.0236 - val_loss: 0.4435 - val_mse: 0.2679
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1050 - mse: 0.0223 - val_loss: 0.4455 - val_mse: 0.2701
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1048 - mse: 0.0231 - val_loss: 0.4480 - val_mse: 0.2728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_11412\2297903707.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test. shape[2]-1] = nuevoValor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1694 - mse: 0.0481 - val_loss: 0.2701 - val_mse: 0.1195
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1718 - mse: 0.0458 - val_loss: 0.2714 - val_mse: 0.1203
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1588 - mse: 0.0415 - val_loss: 0.2700 - val_mse: 0.1193
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1732 - mse: 0.0501 - val_loss: 0.2682 - val_mse: 0.1180
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1528 - mse: 0.0387 - val_loss: 0.2681 - val_mse: 0.1179
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1646 - mse: 0.0460 - val_loss: 0.2706 - val_mse: 0.1197
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1389 - mse: 0.0365 - val_loss: 0.2732 - val_mse: 0.1215
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1480 - mse: 0.0392 - val_loss: 0.2724 - val_mse: 0.1209
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1489 - mse: 0.0458 - val_loss: 0.2689 - val_mse: 0.1183
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1324 - mse: 0.0360 - val_loss: 0.2653 - val_mse: 0.1157
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1501 - mse: 0.0437 - val_loss: 0.2615 - val_mse: 0.1132
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1295 - mse: 0.0374 - val_loss: 0.2599 - val_mse: 0.1123
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1337 - mse: 0.0386 - val_loss: 0.2596 - val_mse: 0.1120
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1244 - mse: 0.0326 - val_loss: 0.2574 - val_mse: 0.1105
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1246 - mse: 0.0369 - val_loss: 0.2552 - val_mse: 0.1089
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1384 - mse: 0.0386 - val_loss: 0.2539 - val_mse: 0.1081
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1320 - mse: 0.0359 - val_loss: 0.2541 - val_mse: 0.1084
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1153 - mse: 0.0281 - val_loss: 0.2559 - val_mse: 0.1096
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1095 - mse: 0.0273 - val_loss: 0.2564 - val_mse: 0.1100
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1233 - mse: 0.0363 - val_loss: 0.2546 - val_mse: 0.1088
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1231 - mse: 0.0325 - val_loss: 0.2521 - val_mse: 0.1072
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1054 - mse: 0.0274 - val_loss: 0.2514 - val_mse: 0.1069
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1184 - mse: 0.0343 - val_loss: 0.2516 - val_mse: 0.1072
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1137 - mse: 0.0325 - val_loss: 0.2510 - val_mse: 0.1069
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1045 - mse: 0.0301 - val_loss: 0.2503 - val_mse: 0.1066
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1083 - mse: 0.0259 - val_loss: 0.2490 - val_mse: 0.1060
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1028 - mse: 0.0242 - val_loss: 0.2476 - val_mse: 0.1053
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1238 - mse: 0.0347 - val_loss: 0.2478 - val_mse: 0.1055
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1099 - mse: 0.0317 - val_loss: 0.2493 - val_mse: 0.1065
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0981 - mse: 0.0240 - val_loss: 0.2496 - val_mse: 0.1067
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1017 - mse: 0.0243 - val_loss: 0.2489 - val_mse: 0.1063
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1135 - mse: 0.0306 - val_loss: 0.2474 - val_mse: 0.1055
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1037 - mse: 0.0251 - val_loss: 0.2465 - val_mse: 0.1051
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1027 - mse: 0.0241 - val_loss: 0.2458 - val_mse: 0.1049
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1022 - mse: 0.0233 - val_loss: 0.2458 - val_mse: 0.1050
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1113 - mse: 0.0294 - val_loss: 0.2456 - val_mse: 0.1049
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0989 - mse: 0.0237 - val_loss: 0.2445 - val_mse: 0.1043
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1054 - mse: 0.0228 - val_loss: 0.2430 - val_mse: 0.1035
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0957 - mse: 0.0206 - val_loss: 0.2419 - val_mse: 0.1029
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1114 - mse: 0.0277 - val_loss: 0.2424 - val_mse: 0.1033
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1116 - mse: 0.0287 - val_loss: 0.2418 - val_mse: 0.1030
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1111 - mse: 0.0283 - val_loss: 0.2408 - val_mse: 0.1026
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1079 - mse: 0.0268 - val_loss: 0.2404 - val_mse: 0.1025
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1098 - mse: 0.0275 - val_loss: 0.2395 - val_mse: 0.1021
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0971 - mse: 0.0213 - val_loss: 0.2390 - val_mse: 0.1019
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1142 - mse: 0.0289 - val_loss: 0.2380 - val_mse: 0.1015
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0947 - mse: 0.0197 - val_loss: 0.2379 - val_mse: 0.1016
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0960 - mse: 0.0205 - val_loss: 0.2372 - val_mse: 0.1014
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1163 - mse: 0.0300 - val_loss: 0.2374 - val_mse: 0.1017
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0955 - mse: 0.0211 - val_loss: 0.2367 - val_mse: 0.1014
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1044 - mse: 0.0256 - val_loss: 0.2359 - val_mse: 0.1011
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0861 - mse: 0.0184 - val_loss: 0.2354 - val_mse: 0.1009
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0984 - mse: 0.0201 - val_loss: 0.2374 - val_mse: 0.1019
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0956 - mse: 0.0197 - val_loss: 0.2389 - val_mse: 0.1027
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1010 - mse: 0.0253 - val_loss: 0.2380 - val_mse: 0.1024
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1083 - mse: 0.0257 - val_loss: 0.2393 - val_mse: 0.1032
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1054 - mse: 0.0259 - val_loss: 0.2415 - val_mse: 0.1046
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1011 - mse: 0.0260 - val_loss: 0.2436 - val_mse: 0.1060
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1036 - mse: 0.0278 - val_loss: 0.2435 - val_mse: 0.1061
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1073 - mse: 0.0276 - val_loss: 0.2425 - val_mse: 0.1058
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1049 - mse: 0.0244 - val_loss: 0.2412 - val_mse: 0.1053
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0930 - mse: 0.0206 - val_loss: 0.2382 - val_mse: 0.1039
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1003 - mse: 0.0219 - val_loss: 0.2363 - val_mse: 0.1030
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0900 - mse: 0.0185 - val_loss: 0.2369 - val_mse: 0.1035
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1060 - mse: 0.0266 - val_loss: 0.2381 - val_mse: 0.1043
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0903 - mse: 0.0205 - val_loss: 0.2394 - val_mse: 0.1051
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1017 - mse: 0.0233 - val_loss: 0.2414 - val_mse: 0.1062
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0904 - mse: 0.0203 - val_loss: 0.2424 - val_mse: 0.1069
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1014 - mse: 0.0240 - val_loss: 0.2424 - val_mse: 0.1069
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1074 - mse: 0.0282 - val_loss: 0.2423 - val_mse: 0.1069
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1145 - mse: 0.0304 - val_loss: 0.2399 - val_mse: 0.1057
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1074 - mse: 0.0243 - val_loss: 0.2364 - val_mse: 0.1039
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1022 - mse: 0.0247 - val_loss: 0.2366 - val_mse: 0.1039
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0977 - mse: 0.0214 - val_loss: 0.2383 - val_mse: 0.1047
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0926 - mse: 0.0206 - val_loss: 0.2416 - val_mse: 0.1064
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0967 - mse: 0.0223 - val_loss: 0.2441 - val_mse: 0.1079
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1125 - mse: 0.0299 - val_loss: 0.2455 - val_mse: 0.1089
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1037 - mse: 0.0288 - val_loss: 0.2445 - val_mse: 0.1085
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1009 - mse: 0.0268 - val_loss: 0.2416 - val_mse: 0.1068
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0975 - mse: 0.0219 - val_loss: 0.2386 - val_mse: 0.1050
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0974 - mse: 0.0200 - val_loss: 0.2383 - val_mse: 0.1049
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0994 - mse: 0.0213 - val_loss: 0.2405 - val_mse: 0.1064
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1084 - mse: 0.0280 - val_loss: 0.2432 - val_mse: 0.1082
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1015 - mse: 0.0282 - val_loss: 0.2436 - val_mse: 0.1085
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1060 - mse: 0.0289 - val_loss: 0.2423 - val_mse: 0.1079
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0825 - mse: 0.0183 - val_loss: 0.2421 - val_mse: 0.1079
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1043 - mse: 0.0279 - val_loss: 0.2416 - val_mse: 0.1077
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0982 - mse: 0.0253 - val_loss: 0.2421 - val_mse: 0.1079
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1001 - mse: 0.0260 - val_loss: 0.2426 - val_mse: 0.1081
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0843 - mse: 0.0194 - val_loss: 0.2441 - val_mse: 0.1091
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0883 - mse: 0.0207 - val_loss: 0.2450 - val_mse: 0.1096
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0757 - mse: 0.0156 - val_loss: 0.2429 - val_mse: 0.1084
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0893 - mse: 0.0194 - val_loss: 0.2417 - val_mse: 0.1075
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0977 - mse: 0.0210 - val_loss: 0.2444 - val_mse: 0.1090
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0830 - mse: 0.0180 - val_loss: 0.2478 - val_mse: 0.1108
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0908 - mse: 0.0207 - val_loss: 0.2508 - val_mse: 0.1126
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0994 - mse: 0.0271 - val_loss: 0.2520 - val_mse: 0.1132
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0787 - mse: 0.0187 - val_loss: 0.2516 - val_mse: 0.1130
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1017 - mse: 0.0283 - val_loss: 0.2509 - val_mse: 0.1124
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0904 - mse: 0.0213 - val_loss: 0.2514 - val_mse: 0.1126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_11412\2297903707.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test. shape[2]-1] = nuevoValor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3076 - mse: 0.1518 - val_loss: 0.5616 - val_mse: 0.5201
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2950 - mse: 0.1344 - val_loss: 0.5614 - val_mse: 0.5186
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2890 - mse: 0.1362 - val_loss: 0.5599 - val_mse: 0.5155
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3280 - mse: 0.1700 - val_loss: 0.5561 - val_mse: 0.5111
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2894 - mse: 0.1455 - val_loss: 0.5506 - val_mse: 0.5058
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2847 - mse: 0.1309 - val_loss: 0.5452 - val_mse: 0.5002
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2698 - mse: 0.1204 - val_loss: 0.5408 - val_mse: 0.4954
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2848 - mse: 0.1385 - val_loss: 0.5371 - val_mse: 0.4912
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2768 - mse: 0.1271 - val_loss: 0.5340 - val_mse: 0.4870
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2610 - mse: 0.1124 - val_loss: 0.5318 - val_mse: 0.4839
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2398 - mse: 0.0992 - val_loss: 0.5299 - val_mse: 0.4807
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2728 - mse: 0.1240 - val_loss: 0.5284 - val_mse: 0.4778
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2565 - mse: 0.1136 - val_loss: 0.5271 - val_mse: 0.4759
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2433 - mse: 0.0997 - val_loss: 0.5270 - val_mse: 0.4761
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2310 - mse: 0.0955 - val_loss: 0.5268 - val_mse: 0.4765
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2529 - mse: 0.1138 - val_loss: 0.5258 - val_mse: 0.4760
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2426 - mse: 0.1030 - val_loss: 0.5251 - val_mse: 0.4758
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2386 - mse: 0.1015 - val_loss: 0.5245 - val_mse: 0.4759
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2573 - mse: 0.1197 - val_loss: 0.5235 - val_mse: 0.4761
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2270 - mse: 0.0984 - val_loss: 0.5231 - val_mse: 0.4771
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2570 - mse: 0.1156 - val_loss: 0.5224 - val_mse: 0.4782
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2315 - mse: 0.1010 - val_loss: 0.5212 - val_mse: 0.4785
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2317 - mse: 0.0960 - val_loss: 0.5200 - val_mse: 0.4788
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2044 - mse: 0.0840 - val_loss: 0.5192 - val_mse: 0.4800
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2447 - mse: 0.1049 - val_loss: 0.5199 - val_mse: 0.4823
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2265 - mse: 0.0991 - val_loss: 0.5216 - val_mse: 0.4852
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2177 - mse: 0.0916 - val_loss: 0.5222 - val_mse: 0.4871
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2340 - mse: 0.1046 - val_loss: 0.5226 - val_mse: 0.4879
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2109 - mse: 0.0889 - val_loss: 0.5231 - val_mse: 0.4887
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2465 - mse: 0.1097 - val_loss: 0.5245 - val_mse: 0.4906
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2310 - mse: 0.0991 - val_loss: 0.5262 - val_mse: 0.4933
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2429 - mse: 0.1104 - val_loss: 0.5274 - val_mse: 0.4957
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2394 - mse: 0.1042 - val_loss: 0.5284 - val_mse: 0.4974
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2197 - mse: 0.0915 - val_loss: 0.5295 - val_mse: 0.4994
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2127 - mse: 0.0899 - val_loss: 0.5307 - val_mse: 0.5017
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2362 - mse: 0.1076 - val_loss: 0.5316 - val_mse: 0.5036
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2408 - mse: 0.1112 - val_loss: 0.5328 - val_mse: 0.5054
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2156 - mse: 0.0910 - val_loss: 0.5335 - val_mse: 0.5061
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2129 - mse: 0.0891 - val_loss: 0.5333 - val_mse: 0.5061
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2365 - mse: 0.1053 - val_loss: 0.5330 - val_mse: 0.5054
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2310 - mse: 0.0972 - val_loss: 0.5336 - val_mse: 0.5061
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2478 - mse: 0.1152 - val_loss: 0.5342 - val_mse: 0.5066
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2173 - mse: 0.0917 - val_loss: 0.5350 - val_mse: 0.5077
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2006 - mse: 0.0816 - val_loss: 0.5358 - val_mse: 0.5089
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2167 - mse: 0.0944 - val_loss: 0.5363 - val_mse: 0.5101
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2325 - mse: 0.1064 - val_loss: 0.5363 - val_mse: 0.5107
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2229 - mse: 0.0974 - val_loss: 0.5361 - val_mse: 0.5109
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2082 - mse: 0.0859 - val_loss: 0.5364 - val_mse: 0.5111
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2202 - mse: 0.0983 - val_loss: 0.5355 - val_mse: 0.5104
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2384 - mse: 0.1081 - val_loss: 0.5349 - val_mse: 0.5100
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2507 - mse: 0.1187 - val_loss: 0.5356 - val_mse: 0.5100
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2063 - mse: 0.0885 - val_loss: 0.5367 - val_mse: 0.5099
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2157 - mse: 0.0898 - val_loss: 0.5371 - val_mse: 0.5089
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2068 - mse: 0.0905 - val_loss: 0.5381 - val_mse: 0.5082
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2351 - mse: 0.1052 - val_loss: 0.5393 - val_mse: 0.5081
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2234 - mse: 0.1045 - val_loss: 0.5405 - val_mse: 0.5085
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2174 - mse: 0.0938 - val_loss: 0.5411 - val_mse: 0.5082
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2298 - mse: 0.1074 - val_loss: 0.5411 - val_mse: 0.5072
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2146 - mse: 0.0935 - val_loss: 0.5407 - val_mse: 0.5058
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2069 - mse: 0.0901 - val_loss: 0.5395 - val_mse: 0.5040
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2068 - mse: 0.0976 - val_loss: 0.5380 - val_mse: 0.5013
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2092 - mse: 0.0925 - val_loss: 0.5386 - val_mse: 0.5003
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2332 - mse: 0.1095 - val_loss: 0.5398 - val_mse: 0.4998
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2138 - mse: 0.0944 - val_loss: 0.5409 - val_mse: 0.4998
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2228 - mse: 0.1027 - val_loss: 0.5407 - val_mse: 0.4990
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2151 - mse: 0.1003 - val_loss: 0.5389 - val_mse: 0.4973
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2166 - mse: 0.1017 - val_loss: 0.5360 - val_mse: 0.4950
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2053 - mse: 0.0900 - val_loss: 0.5333 - val_mse: 0.4927
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2151 - mse: 0.0929 - val_loss: 0.5312 - val_mse: 0.4910
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2161 - mse: 0.0970 - val_loss: 0.5293 - val_mse: 0.4896
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2100 - mse: 0.0922 - val_loss: 0.5274 - val_mse: 0.4882
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2352 - mse: 0.1027 - val_loss: 0.5267 - val_mse: 0.4875
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2017 - mse: 0.0817 - val_loss: 0.5270 - val_mse: 0.4878
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2168 - mse: 0.0867 - val_loss: 0.5271 - val_mse: 0.4875
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2071 - mse: 0.0845 - val_loss: 0.5277 - val_mse: 0.4878
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2372 - mse: 0.1068 - val_loss: 0.5277 - val_mse: 0.4871
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1918 - mse: 0.0747 - val_loss: 0.5276 - val_mse: 0.4863
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2027 - mse: 0.0846 - val_loss: 0.5271 - val_mse: 0.4854
# Epoch 79/100
# ...
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1949 - mse: 0.0737 - val_loss: 0.5189 - val_mse: 0.4719
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2055 - mse: 0.0804 - val_loss: 0.5185 - val_mse: 0.4707
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1995 - mse: 0.0797 - val_loss: 0.5181 - val_mse: 0.4689
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1990 - mse: 0.0803 - val_loss: 0.5180 - val_mse: 0.4681
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1861 - mse: 0.0738 - val_loss: 0.5186 - val_mse: 0.4681
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2043 - mse: 0.0843 - val_loss: 0.5200 - val_mse: 0.4692
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2070 - mse: 0.0885 - val_loss: 0.5216 - val_mse: 0.4706
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2036 - mse: 0.0843 - val_loss: 0.5235 - val_mse: 0.4721
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1925 - mse: 0.0797 - val_loss: 0.5248 - val_mse: 0.4726
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2132 - mse: 0.0910 - val_loss: 0.5257 - val_mse: 0.4728
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2022 - mse: 0.0884 - val_loss: 0.5265 - val_mse: 0.4732
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_11412\2297903707.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test. shape[2]-1] = nuevoValor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2197 - mse: 0.0708 - val_loss: 0.5423 - val_mse: 0.5631
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2039 - mse: 0.0638 - val_loss: 0.5421 - val_mse: 0.5640
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1995 - mse: 0.0625 - val_loss: 0.5418 - val_mse: 0.5651
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2024 - mse: 0.0623 - val_loss: 0.5414 - val_mse: 0.5665
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2135 - mse: 0.0666 - val_loss: 0.5412 - val_mse: 0.5679
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1883 - mse: 0.0543 - val_loss: 0.5412 - val_mse: 0.5689
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1758 - mse: 0.0489 - val_loss: 0.5410 - val_mse: 0.5693
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1558 - mse: 0.0418 - val_loss: 0.5408 - val_mse: 0.5696
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1849 - mse: 0.0554 - val_loss: 0.5403 - val_mse: 0.5697
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1605 - mse: 0.0448 - val_loss: 0.5397 - val_mse: 0.5695
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1594 - mse: 0.0413 - val_loss: 0.5392 - val_mse: 0.5696
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1608 - mse: 0.0462 - val_loss: 0.5389 - val_mse: 0.5702
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1607 - mse: 0.0412 - val_loss: 0.5383 - val_mse: 0.5703
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1517 - mse: 0.0386 - val_loss: 0.5378 - val_mse: 0.5704
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1407 - mse: 0.0340 - val_loss: 0.5371 - val_mse: 0.5704
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1440 - mse: 0.0353 - val_loss: 0.5364 - val_mse: 0.5703
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1529 - mse: 0.0392 - val_loss: 0.5357 - val_mse: 0.5697
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1370 - mse: 0.0336 - val_loss: 0.5353 - val_mse: 0.5693
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1461 - mse: 0.0372 - val_loss: 0.5350 - val_mse: 0.5680
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1502 - mse: 0.0384 - val_loss: 0.5346 - val_mse: 0.5658
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1426 - mse: 0.0357 - val_loss: 0.5342 - val_mse: 0.5635
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1381 - mse: 0.0329 - val_loss: 0.5341 - val_mse: 0.5623
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1301 - mse: 0.0292 - val_loss: 0.5341 - val_mse: 0.5612
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1462 - mse: 0.0357 - val_loss: 0.5342 - val_mse: 0.5604
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1303 - mse: 0.0307 - val_loss: 0.5343 - val_mse: 0.5597
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1299 - mse: 0.0299 - val_loss: 0.5342 - val_mse: 0.5592
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1353 - mse: 0.0315 - val_loss: 0.5333 - val_mse: 0.5580
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1241 - mse: 0.0276 - val_loss: 0.5326 - val_mse: 0.5569
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1309 - mse: 0.0292 - val_loss: 0.5316 - val_mse: 0.5560
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1308 - mse: 0.0292 - val_loss: 0.5310 - val_mse: 0.5553
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1381 - mse: 0.0316 - val_loss: 0.5303 - val_mse: 0.5542
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1336 - mse: 0.0304 - val_loss: 0.5292 - val_mse: 0.5524
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1245 - mse: 0.0281 - val_loss: 0.5278 - val_mse: 0.5502
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1392 - mse: 0.0319 - val_loss: 0.5262 - val_mse: 0.5479
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1373 - mse: 0.0327 - val_loss: 0.5245 - val_mse: 0.5454
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1225 - mse: 0.0271 - val_loss: 0.5231 - val_mse: 0.5432
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1199 - mse: 0.0251 - val_loss: 0.5218 - val_mse: 0.5415
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1201 - mse: 0.0251 - val_loss: 0.5211 - val_mse: 0.5406
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1264 - mse: 0.0263 - val_loss: 0.5206 - val_mse: 0.5402
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1318 - mse: 0.0288 - val_loss: 0.5205 - val_mse: 0.5400
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1382 - mse: 0.0322 - val_loss: 0.5208 - val_mse: 0.5403
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1256 - mse: 0.0278 - val_loss: 0.5211 - val_mse: 0.5403
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1173 - mse: 0.0251 - val_loss: 0.5209 - val_mse: 0.5400
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1309 - mse: 0.0296 - val_loss: 0.5204 - val_mse: 0.5391
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1239 - mse: 0.0262 - val_loss: 0.5194 - val_mse: 0.5377
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1345 - mse: 0.0322 - val_loss: 0.5180 - val_mse: 0.5357
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1211 - mse: 0.0246 - val_loss: 0.5173 - val_mse: 0.5343
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1223 - mse: 0.0261 - val_loss: 0.5168 - val_mse: 0.5333
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1250 - mse: 0.0284 - val_loss: 0.5165 - val_mse: 0.5327
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1271 - mse: 0.0279 - val_loss: 0.5161 - val_mse: 0.5321
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1144 - mse: 0.0238 - val_loss: 0.5158 - val_mse: 0.5315
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1156 - mse: 0.0237 - val_loss: 0.5157 - val_mse: 0.5311
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1253 - mse: 0.0278 - val_loss: 0.5154 - val_mse: 0.5307
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1211 - mse: 0.0269 - val_loss: 0.5152 - val_mse: 0.5305
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1150 - mse: 0.0242 - val_loss: 0.5153 - val_mse: 0.5307
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1168 - mse: 0.0259 - val_loss: 0.5157 - val_mse: 0.5313
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1109 - mse: 0.0231 - val_loss: 0.5157 - val_mse: 0.5313
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1122 - mse: 0.0229 - val_loss: 0.5155 - val_mse: 0.5307
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1248 - mse: 0.0288 - val_loss: 0.5152 - val_mse: 0.5297
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1138 - mse: 0.0233 - val_loss: 0.5147 - val_mse: 0.5287
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1282 - mse: 0.0294 - val_loss: 0.5143 - val_mse: 0.5281
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1050 - mse: 0.0209 - val_loss: 0.5141 - val_mse: 0.5278
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1190 - mse: 0.0249 - val_loss: 0.5139 - val_mse: 0.5275
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1115 - mse: 0.0229 - val_loss: 0.5136 - val_mse: 0.5269
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1175 - mse: 0.0270 - val_loss: 0.5130 - val_mse: 0.5257
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1130 - mse: 0.0229 - val_loss: 0.5122 - val_mse: 0.5242
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1187 - mse: 0.0251 - val_loss: 0.5113 - val_mse: 0.5225
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1153 - mse: 0.0273 - val_loss: 0.5107 - val_mse: 0.5213
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1195 - mse: 0.0281 - val_loss: 0.5101 - val_mse: 0.5198
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1247 - mse: 0.0279 - val_loss: 0.5096 - val_mse: 0.5182
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1168 - mse: 0.0272 - val_loss: 0.5094 - val_mse: 0.5168
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1198 - mse: 0.0283 - val_loss: 0.5092 - val_mse: 0.5157
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1032 - mse: 0.0221 - val_loss: 0.5090 - val_mse: 0.5153
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1253 - mse: 0.0307 - val_loss: 0.5088 - val_mse: 0.5149
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1104 - mse: 0.0232 - val_loss: 0.5085 - val_mse: 0.5142
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1219 - mse: 0.0293 - val_loss: 0.5082 - val_mse: 0.5135
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1183 - mse: 0.0290 - val_loss: 0.5080 - val_mse: 0.5129
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1082 - mse: 0.0258 - val_loss: 0.5081 - val_mse: 0.5128
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1143 - mse: 0.0261 - val_loss: 0.5083 - val_mse: 0.5128
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1256 - mse: 0.0316 - val_loss: 0.5081 - val_mse: 0.5122
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1202 - mse: 0.0280 - val_loss: 0.5078 - val_mse: 0.5115
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1298 - mse: 0.0334 - val_loss: 0.5077 - val_mse: 0.5110
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1207 - mse: 0.0309 - val_loss: 0.5077 - val_mse: 0.5104
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1103 - mse: 0.0253 - val_loss: 0.5074 - val_mse: 0.5093
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1126 - mse: 0.0241 - val_loss: 0.5071 - val_mse: 0.5085
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1189 - mse: 0.0299 - val_loss: 0.5065 - val_mse: 0.5073
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1140 - mse: 0.0271 - val_loss: 0.5057 - val_mse: 0.5060
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1186 - mse: 0.0292 - val_loss: 0.5054 - val_mse: 0.5056
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1209 - mse: 0.0295 - val_loss: 0.5052 - val_mse: 0.5053
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1113 - mse: 0.0256 - val_loss: 0.5049 - val_mse: 0.5045
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1200 - mse: 0.0289 - val_loss: 0.5045 - val_mse: 0.5032
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1247 - mse: 0.0309 - val_loss: 0.5043 - val_mse: 0.5023
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1188 - mse: 0.0315 - val_loss: 0.5042 - val_mse: 0.5019
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1066 - mse: 0.0247 - val_loss: 0.5033 - val_mse: 0.5004
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1224 - mse: 0.0315 - val_loss: 0.5020 - val_mse: 0.4980
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1077 - mse: 0.0266 - val_loss: 0.5007 - val_mse: 0.4957
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1155 - mse: 0.0294 - val_loss: 0.4995 - val_mse: 0.4935
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1268 - mse: 0.0323 - val_loss: 0.4983 - val_mse: 0.4911
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1194 - mse: 0.0296 - val_loss: 0.4974 - val_mse: 0.4891
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1133 - mse: 0.0258 - val_loss: 0.4971 - val_mse: 0.4884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C:\Users\JoCel\AppData\Local\Temp\ipykernel_11412\2297903707.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test. shape[2]-1] = nuevoValor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#             producto 635  producto 350  producto 176  producto 303  \
# fecha
# 2021-01-01        235479         47304         33010         11046
# 2021-02-01        248901         50583         32357         10861
# 2021-03-01        207836         45345         33889         12034
# 2021-04-01        244265         43610         33633         10354
# 2021-05-01        211703         40988         30170         10229
# 2021-06-01        206378         39661         27310          8496
# 2021-07-01        213704         41530         32738          7890
# 2021-08-01        198158         40759         35292          9424
# 2021-09-01        229401         44209         37090          9596
# 2021-10-01        212583         43879         37316         10643
# 2021-11-01        221401         42383         36512          9677
# 2021-12-01        244147         46626         37225         10020
#
#             producto 304
# fecha
# 2021-01-01          9166
# 2021-02-01         10594
# 2021-03-01         11460
# 2021-04-01          9896
# 2021-05-01          8160
# 2021-06-01          7467
# 2021-07-01          7449
# 2021-08-01          7846
# 2021-09-01          7302
# 2021-10-01          6861
# 2021-11-01          7024
# 2021-12-01          7190

# %%
print(future_data)
print(datos)
# future_data.plot()
# Out:
#             producto 635  producto 350  producto 176  producto 303  \
# fecha
# 2021-01-01        235479         47304         33010         11046
# 2021-02-01        248901         50583         32357         10861
# 2021-03-01        207836         45345         33889         12034
# 2021-04-01        244265         43610         33633         10354
# 2021-05-01        211703         40988         30170         10229
# 2021-06-01        206378         39661         27310          8496
# 2021-07-01        213704         41530         32738          7890
# 2021-08-01        198158         40759         35292          9424
# 2021-09-01        229401         44209         37090          9596
# 2021-10-01        212583         43879         37316         10643
# 2021-11-01        221401         42383         36512          9677
# 2021-12-01        244147         46626         37225         10020
#
#             producto 304
# fecha
# 2021-01-01          9166
# 2021-02-01         10594
# 2021-03-01         11460
# 2021-04-01          9896
# 2021-05-01          8160
# 2021-06-01          7467
# 2021-07-01          7449
# 2021-08-01          7846
# 2021-09-01          7302
# 2021-10-01          6861
# 2021-11-01          7024
# 2021-12-01          7190
#          producto 635  producto 350  producto 176  producto 303  producto 304
# fecha
# 2015-01        109526         22519         13743          6845          6833
# 2015-02        115904         22635         14193          8046          6575
# 2015-03        124280         25132         14129          8338          6815
# 2015-04        123077         25873         13843          8428          6967
# 2015-05        130781         26951         14953          8650          7186
# ...               ...           ...           ...           ...           ...
# 2020-08        145750         40411         39305          6806          5356
# 2020-09        150871         36145         36609          6656          4685
# 2020-10        161751         37648         35705          6461          5379
# 2020-11        183509         38983         37041          6905          5242
# 2020-12        220930         55432         51147          9052          8243
#
# [72 rows x 5 columns]

# %%
    datos.index = pd.to_datetime(datos.index)
    future_data.index = pd.to_datetime(future_data.index)

    #Graficar los dataframes
    for i in range(len(datos.columns)):
        data = datos[datos.columns[i]][:]
        plt.plot(data.index, data,label='Historial 2015 - 2020')
        plt.plot(future_data.index, future_data[future_data.columns[i]], label='Predicción 2021 - 2022')
        xtics = data.index.union(future_data.index)[::8]

        plt.xticks(xtics)
        plt.xlabel('Fecha')
        plt.ylabel('Ventas')
        plt.title('Predicción de la demanda del {p0} para el año del 2021'.format(p0=datos.columns[i]))


        plt.legend()
        plt.show()
    future_data
# Out:
#             producto 635  producto 350  producto 176  producto 303  \
# fecha
# 2021-01-01        235479         47304         33010         11046
# 2021-02-01        248901         50583         32357         10861
# 2021-03-01        207836         45345         33889         12034
# 2021-04-01        244265         43610         33633         10354
# 2021-05-01        211703         40988         30170         10229
# 2021-06-01        206378         39661         27310          8496
# 2021-07-01        213704         41530         32738          7890
# 2021-08-01        198158         40759         35292          9424
# 2021-09-01        229401         44209         37090          9596
# 2021-10-01        212583         43879         37316         10643
# 2021-11-01        221401         42383         36512          9677
# 2021-12-01        244147         46626         37225         10020
#
#             producto 304
# fecha
# 2021-01-01          9166
# 2021-02-01         10594
# 2021-03-01         11460
# 2021-04-01          9896
# 2021-05-01          8160
# 2021-06-01          7467
# 2021-07-01          7449
# 2021-08-01          7846
# 2021-09-01          7302
# 2021-10-01          6861
# 2021-11-01          7024
# 2021-12-01          7190
